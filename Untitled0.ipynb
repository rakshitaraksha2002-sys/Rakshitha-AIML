# %%
print("HAPPPY NEW YEAR 2026")
# Out:
# HAPPPY NEW YEAR 2026

# %%
def greeting(year,name):
print("HAPPY NEW YEAR",",""GREETINGS TO",name)
greeting(2026,"MAHALAKSHMI")
# Out:
#   File "/tmp/ipython-input-2218921998.py", line 2
#     print("HAPPY NEW YEAR",",""GREETINGS TO",name)
#     ^
# IndentationError: expected an indented block after function definition on line 1
