# %%
import numpy as np
a=np.array([10,20,30,40,50])
mask=np.array([True,False,True,False,True])
a[mask]
# Out:
# array([10, 30, 50])

# %%
a=np.array([10,20,30,40,50])
idx=np.array([4,0,4,1])
a[idx]
# Out:
# array([50, 10, 50, 20])

# %%
a=np.array([1,2,3,4,5,6])
mask=np.array([True,False,True,False,True,False])
a[mask]
# Out:
# array([1, 3, 5])

# %%
a=np.array([[1,2],[3,4]])
b=np.array([10,20,30])
a+b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1180939259.py in <cell line: 0>()
#       1 a=np.array([[1,2],[3,4]])
#       2 b=np.array([10,20,30])
# ----> 3 a+b
#
# ValueError: operands could not be broadcast together with shapes (2,2) (3,)

# %%
a=np.array([[1,2],[3,4],[5,6]])
print("a=",a)

a[:,[False,True]]
# Out:
# a= [[1 2]
#  [3 4]
#  [5 6]]
# array([[2],
#        [4],
#        [6]])

# %%
a[:,1]
# Out:
# array([2, 4, 6])

# %%
a[:,0]
# Out:
# array([1, 3, 5])

# %%
a=np.array([[1,2,3],[3,4,5]])
b=np.array([10,20,30])
a[b]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1488439792.py in <cell line: 0>()
#       1 a=np.array([[1,2,3],[3,4,5]])
#       2 b=np.array([10,20,30])
# ----> 3 a[b]
#
# IndexError: index 10 is out of bounds for axis 0 with size 2

# %%
a=np.array([[1,2,6],[3,4,5]])
b=np.array([10,20,30])
a+b
# Out:
# array([[11, 22, 36],
#        [13, 24, 35]])

# %%
a=np.array([[1,2],[3,4]])
b=np.array([0,1])
a[b]
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a=np.array([[1,2,3],[4,5,6]])
b=np.array([10,20,30])
print(a)
a+b
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[11, 22, 33],
#        [14, 25, 36]])

# %%
a*b
# Out:
# array([[ 10,  40,  90],
#        [ 40, 100, 180]])

# %%
a=np.array([[1,2,3],[4,5,6]])
b=np.array([1],
           [2],
           [3])
print(a.shape)
print(b.shape)
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-626697953.py in <cell line: 0>()
#       1 a=np.array([[1,2,3],[4,5,6]])
# ----> 2 b=np.array([1],
#       3            [2],
#       4            [3])
#       5 print(a.shape)
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given

# %%
a=np.array([[1,2,3],[4,5,6]])
b=np.array([[3],[4]])
print(a.shape)
print(b.shape)
a*b
# Out:
# (2, 3)
# (2, 1)
# array([[ 3,  6,  9],
#        [16, 20, 24]])

# %%
a=np.array([1,2,3,4,5])
a[a>2]
# Out:
# array([3, 4, 5])

# %%
a=np.array([[1,2,3],[4,5,6]])
b=np.array([[10],[20],[30]])
print(a.shape)
print(b.shape)
a+b
# Out:
# (2, 3)
# (3, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1003120309.py in <cell line: 0>()
#       3 print(a.shape)
#       4 print(b.shape)
# ----> 5 a+b
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,1)
