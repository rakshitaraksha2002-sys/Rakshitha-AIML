# %%
optimum_nutrient_availability = True
fertilizer_application = False
print("AND:",optimum_nutrient_availability and fertilizer_application)
print("OR:",optimum_nutrient_availability or fertilizer_application)
print("NOT:",not optimum_nutrient_availability)
# Out:
# AND: False
# OR: True
# NOT: True
